# %%
def stepwise_iterations(n,k, forward=True):
    if forward:
        return sum(n-i for i in range(k))
    else:
        return sum(n-i for i in range(n-k))
    
def iter_count(heuristic, n, k):
    if "Variable Flooring" in heuristic:
        return 1
    elif "Backward Stepwise Regression" in heuristic:
        return stepwise_iterations(n,k, forward=False)
    else:
        return stepwise_iterations(n,k, forward=True)
    
import math
def possible_solutions(n,k):
    return math.comb(n,k)

def possible_tree_size(n,k):
    return 2 * math.comb(n,k) - 1
    
print(f"{stepwise_iterations(500,10):,}")
print(f"{stepwise_iterations(500,10,forward=False):,}")
print(f"{possible_solutions(500,10):,}")
print(f"{possible_tree_size(500,10):,}")
# Out:
# 999
# 125,247
# 245,810,588,801,891,098,700
# 491,621,177,603,782,197,399

# %%
import pandas as pd
import matplotlib.pyplot as plt

# For Madelon n = 500


fig,ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))



actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_MYOCARDIAL_MOSEK_Least Fractional_Forward Stepwise Regression No Penalty_8_copy.csv")
ax[0,0].plot(actual_data["iteration"], actual_data["UB"], label = "UB Fwd Stepwise")
ax[0,0].plot(actual_data["iteration"], actual_data["LB"], label = "LB Fwd Stepwise")
ax[0,0].legend()
ax[0,0].set_title("Convergence (MADELON)")
ax[0,0].set_ylabel("Objective")
ax[0,0].set_xlabel("Iteration")
ax[0,1].plot(actual_data["iteration"], actual_data["num_subproblems"], label="Fwd Stepwise")
ax[0,1].set_title("Open Problem Plot (MADELON)")
ax[0,1].set_ylabel("Open Subproblems")
ax[0,1].set_xlabel("Iteration")

actual_data["remaining_tree_size"] = actual_data["remaining_tree_size"].apply(int)
max_val = actual_data["remaining_tree_size"].max()
actual_data["tree_percent"] = actual_data["remaining_tree_size"].apply(lambda x: max_val - x)
ax[0,2].plot(actual_data["iteration"], actual_data["tree_percent"], label="Fwd Stepwise")
ax[0,2].set_title("Tree Exploration/Pruning Plot (MADELON)")
ax[0,2].set_ylabel("Number of Problems")
ax[0,2].set_xlabel("Iteration")

actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_MADELON_MOSEK_Most Fractional_No Heuristic_10 copy.csv")
ax[0,0].plot(actual_data["iteration"], actual_data["UB"], label = "UB No Heuristic")
ax[0,0].plot(actual_data["iteration"], actual_data["LB"], label = "LB No Heuristic")
ax[0,0].legend()
ax[0,0].set_title("Convergence (MADELON)")
ax[0,0].set_ylabel("Objective")
ax[0,0].set_xlabel("Iteration")
ax[0,1].plot(actual_data["iteration"], actual_data["num_subproblems"], label="No Heuristic")
ax[0,1].legend()
ax[0,1].set_title("Open Problem Plot (MADELON)")
ax[0,1].set_ylabel("Open Subproblems")
ax[0,1].set_xlabel("Iteration")

actual_data["remaining_tree_size"] = actual_data["remaining_tree_size"].apply(int)
max_val = actual_data["remaining_tree_size"].max()
actual_data["tree_percent"] = actual_data["remaining_tree_size"].apply(lambda x: max_val - x)
ax[0,2].plot(actual_data["iteration"], actual_data["tree_percent"], label="No Heuristic")
ax[0,2].legend()
ax[0,2].set_title("Tree Exploration/Pruning Plot (MADELON)")
ax[0,2].set_ylabel("Number of Problems")
ax[0,2].set_xlabel("Iteration")


actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_IONOSPHERE_MOSEK_Least Fractional_No Heuristic_{7}.csv")
ax[1,0].plot(actual_data["iteration"], actual_data["UB"], label = "UB")
ax[1,0].plot(actual_data["iteration"], actual_data["LB"], label = "LB")
ax[1,0].legend()
ax[1,0].set_title("Convergence (IONOSPHERE)")
ax[1,0].set_ylabel("Objective")
ax[1,0].set_xlabel("Iteration")
ax[1,1].plot(actual_data["iteration"], actual_data["num_subproblems"])
ax[1,1].set_title("Open Problem Plot (IONOSPHERE)")
ax[1,1].set_ylabel("Open Subproblems")
ax[1,1].set_xlabel("Iteration")

actual_data["remaining_tree_size"] = actual_data["remaining_tree_size"].apply(int)
max_val = actual_data["remaining_tree_size"].max()
actual_data["tree_percent"] = actual_data["remaining_tree_size"].apply(lambda x: max_val - x)
ax[1,2].plot(actual_data["iteration"], actual_data["tree_percent"])
ax[1,2].set_title("Tree Exploration/Pruning Plot (IONOSPHERE)")
ax[1,2].set_ylabel("Number of Problems")
ax[1,2].set_xlabel("Iteration")

fig.show()
# Out:
# /var/folders/nv/fbl0kxf95nj0krqsjrxv76z80000gn/T/ipykernel_54168/16045821.py:74: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# For Madelon n = 500


fig,ax = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_greedy_MADELON_mosek_mosek_No Heuristic_10.csv", skiprows=[1])
actual_data = actual_data.drop_duplicates(subset="iteration", keep="first")
ax[0,0].plot(actual_data["iteration"], actual_data["UB"], label = "UB greedy")
ax[0,0].plot(actual_data["iteration"], actual_data["LB"], label = "LB greedy")
ax[0,0].legend()
ax[0,0].set_title("Convergence (MADELON)")
ax[0,0].set_ylabel("Objective")
ax[0,0].set_xlabel("Iteration")
ax[0,1].plot(actual_data["iteration"], actual_data["num_subproblems"], label="Greedy")
ax[0,1].set_title("Open Problem Plot (MADELON)")
ax[0,1].set_ylabel("Open Subproblems")
ax[0,1].set_xlabel("Iteration")

actual_data["remaining_tree_size"] = actual_data["remaining_tree_size"].apply(int)
max_val = actual_data["remaining_tree_size"].max()
actual_data["tree_percent"] = actual_data["remaining_tree_size"].apply(lambda x: max_val - x)
ax[0,2].plot(actual_data["iteration"], actual_data["tree_percent"], label="Greedy")
ax[0,2].set_title("Tree Exploration/Pruning Plot (MADELON)")
ax[0,2].set_ylabel("Number of Problems")
ax[0,2].set_xlabel("Iteration")

actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_MADELON_MOSEK_Most Fractional_Forward Stepwise Regression No Penalty_10.csv")
ax[1,0].plot(actual_data["iteration"], actual_data["UB"], label = "UB Normal")
ax[1,0].plot(actual_data["iteration"], actual_data["LB"], label = "LB Normal")
ax[1,0].legend()
ax[1,0].set_title("Convergence (Stepwise Initial UB)")
ax[1,0].set_ylabel("Objective")
ax[1,0].set_xlabel("Iteration")
ax[1,1].plot(actual_data["iteration"], actual_data["num_subproblems"], label="Normal")
ax[1,1].set_title("Open Problem Plot (Stepwise Initial UB)")
ax[1,1].set_ylabel("Open Subproblems")
ax[1,1].set_xlabel("Iteration")

actual_data["remaining_tree_size"] = actual_data["remaining_tree_size"].apply(int)
max_val = actual_data["remaining_tree_size"].max()
actual_data["tree_percent"] = actual_data["remaining_tree_size"].apply(lambda x: max_val - x)
ax[1,2].plot(actual_data["iteration"], actual_data["tree_percent"], label="Normal")
ax[1,2].set_title("Tree Exploration/Pruning Plot (Stepwise Initial UB)")
ax[1,2].set_ylabel("Number of Problems")
ax[1,2].set_xlabel("Iteration")


actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_greedy_MADELON_mosek_mosek_No Heuristic_10.csv")
actual_data = actual_data.drop_duplicates(subset="iteration", keep="last")
ax[1,0].plot(actual_data["iteration"], actual_data["UB"], label = "UB greedy")
ax[1,0].plot(actual_data["iteration"], actual_data["LB"], label = "LB greedy")
ax[1,0].legend()
ax[1,0].set_title("Convergence (MADELON)")
ax[1,0].set_ylabel("Objective")
ax[1,0].set_xlabel("Iteration")
ax[1,1].plot(actual_data["iteration"], actual_data["num_subproblems"], label="Greedy")
ax[1,1].set_title("Open Problem Plot (MADELON)")
ax[1,1].set_ylabel("Open Subproblems")
ax[1,1].set_xlabel("Iteration")

actual_data["remaining_tree_size"] = actual_data["remaining_tree_size"].apply(int)
max_val = actual_data["remaining_tree_size"].max()
actual_data["tree_percent"] = actual_data["remaining_tree_size"].apply(lambda x: max_val - x)
ax[1,2].plot(actual_data["iteration"], actual_data["tree_percent"], label="Greedy")
ax[1,2].set_title("Tree Exploration/Pruning Plot (MADELON)")
ax[1,2].set_ylabel("Number of Problems")
ax[1,2].set_xlabel("Iteration")

actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_MADELON_MOSEK_Most Fractional_No Heuristic_10 copy.csv")
ax[0,0].plot(actual_data["iteration"], actual_data["UB"], label = "UB Normal")
ax[0,0].plot(actual_data["iteration"], actual_data["LB"], label = "LB Normal")
ax[0,0].legend()
ax[0,0].set_title("Convergence (No Initial UB)")
ax[0,0].set_ylabel("Objective")
ax[0,0].set_xlabel("Iteration")
ax[0,1].plot(actual_data["iteration"], actual_data["num_subproblems"], label="Normal")
ax[0,1].legend()
ax[0,1].set_title("Open Problem Plot (No Initial UB)")
ax[0,1].set_ylabel("Open Subproblems")
ax[0,1].set_xlabel("Iteration")

actual_data["remaining_tree_size"] = actual_data["remaining_tree_size"].apply(int)
max_val = actual_data["remaining_tree_size"].max()
actual_data["tree_percent"] = actual_data["remaining_tree_size"].apply(lambda x: max_val - x)
ax[0,2].plot(actual_data["iteration"], actual_data["tree_percent"], label="Normal")
ax[0,2].legend()
ax[0,2].set_title("Tree Exploration/Pruning Plot (No Initial UB)")
ax[0,2].set_ylabel("Number of Problems")
ax[0,2].set_xlabel("Iteration")




ax[1,2].set_xlabel("Iteration")

fig.show()
# Out:
# /var/folders/nv/fbl0kxf95nj0krqsjrxv76z80000gn/T/ipykernel_42259/2504593987.py:99: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# For Ionosphere n = 34

n=34

k_vals = []
solve_iters = []
forward_solve_iters = []
backward_solve_iters = []

for k in sorted(range(1,34), reverse=True):
    actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_IONOSPHERE_MOSEK_Least Fractional_No Heuristic_{k}.csv")
    k_vals.append(k)
    solve_iters.append(actual_data['iteration'].max())
    forward_solve_iters.append(stepwise_iterations(n,k))
    backward_solve_iters.append(stepwise_iterations(n,k,forward=False))
    # print(heuristic_data.head())
    # print(actual_data.head())
    
#     plt.plot(actual_data["iteration"], (actual_data["UB"] - actual_data["LB"]) / actual_data["LB"], label = f"{k}")

# plt.legend()
# plt.show()


    
plt.plot(k_vals, solve_iters, label="B&B")
plt.plot(k_vals, forward_solve_iters, label="Forward Stepwise Regression")
plt.plot(k_vals, backward_solve_iters, label="Backward Stepwise Regression")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# For Ionosphere n = 34

n=34

forward_improve_iterations = {}
complete_iterations = {}
forward_optimality_ratio = {}

for k in range(2,21,2):
    actual_data = pd.read_csv(f"/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_MYOCARDIAL_MOSEK_Least Fractional_Forward Stepwise Regression No Penalty_{k}.csv")
    
    if actual_data["UB"].min() < actual_data["UB"].max():
        forward_improve_iterations[k] = actual_data[actual_data["UB"] < actual_data["UB"].max()]["iteration"].min()
        complete_iterations[k] = actual_data["iteration"].max()

    forward_optimality_ratio[k] = actual_data["UB"].min() / actual_data["UB"].max()
            

    # print(heuristic_data.head())
    # print(actual_data.head())
    
#     plt.plot(actual_data["iteration"], (actual_data["UB"] - actual_data["LB"]) / actual_data["LB"], label = f"{k}")

# plt.legend()
# plt.show()

fig, axes = plt.subplots(2, 2, figsize=(15, 15))  # 10 inches wide, 4 inches tall

axes[1,0].plot(forward_improve_iterations.keys(), forward_improve_iterations.values(), label="Forward Stepwise")
#axes[1,0].plot(k_vals, backward_solve_epochs, label="Backward Stepwise")
#axes[1,0].plot(k_vals, [1 for _ in k_vals], label = "Iteration Equivalence Threshold", linestyle='dashed')
#axes[1,0].legend()
axes[1,0].set_title("Relative Iterations to Reach Eqivalent Solution")
axes[1,0].set_xlabel("$l_0$ Constraint")
axes[1,0].set_ylabel("Relative Iterations")

axes[1,1].plot(complete_iterations.keys(), complete_iterations.values(), label="Forward Stepwise")
#axes[1,1].plot(k_vals, backward_complete_epochs, label="Backward Stepwise")
#axes[1,1].plot(k_vals, [1 for _ in k_vals], label = "Iteration Equivalence Threshold", linestyle='dashed')
#axes[1,1].legend()
axes[1,1].set_title("Relative Iterations to Completion")
axes[1,1].set_xlabel("l0 Constraint")
axes[1,1].set_ylabel("Relative Iterations")

axes[0,1].plot(forward_optimality_ratio.keys(), forward_optimality_ratio.values(), label="Forward Stepwise")
#axes[0,1].plot(k_vals, backward_optimality_ratio, label="Backward Stepwise")
#axes[0,1].plot(k_vals, [1 for _ in k_vals], label = "Equivalence Threshold", linestyle='dashed')
#axes[0,1].legend()
axes[0,1].set_title("Objective Ratio (lower better)")
axes[0,1].set_xlabel("l0 Constraint")
axes[0,1].set_ylabel("Relative Objective")

plt.tight_layout()
fig.show()
# Out:
# /var/folders/nv/fbl0kxf95nj0krqsjrxv76z80000gn/T/ipykernel_62809/2189771476.py:57: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
dual_data = pd.read_csv("/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_MYOCARDIAL_DUAL_MOSEK_Random Var Selector_No Heuristic_4.csv")
print(dual_data[dual_data["UB"] < dual_data["LB"]])
plt.plot(dual_data["iteration"], dual_data["UB"], label="UB")
plt.plot(dual_data["iteration"], dual_data["LB"], label="LB")
plt.legend()
# Out:
# Empty DataFrame
# Columns: [iteration, time, UB, LB, num_subproblems, remaining_tree_size]
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt

dual_data = pd.read_csv("/Users/jamesjones/Research_Weijun/LogRegpy/tests/test_data/test_MYOCARDIAL_MOSEK_Least Fractional_No Heuristic_100_copy.csv")
# print(dual_data[dual_data["UB"] < dual_data["LB"]])
# plt.plot(dual_data["iteration"], dual_data["UB"], label="UB")
# plt.plot(dual_data["iteration"], dual_data["LB"], label="LB")
# plt.legend()
# plt.show()
plt.rcParams.update({'font.size': 14}) 

dual_data.loc[dual_data.index[-1], "num_subproblems"] = 0

fig, ax = plt.subplots(1,2, figsize=(10, 4))
ax[0].plot(dual_data["iteration"], dual_data["num_subproblems"])
ax[0].set_xlabel("Iteration")
ax[0].set_title("Number of Open Subproblems")


ax[1].plot(dual_data["iteration"], dual_data["remaining_tree_size"])
ax[1].set_xlabel("Iteration")
ax[1].set_title("Remaining Tree Size")


# Set RGB background color for the figure (outer)
fig.patch.set_facecolor((214/255, 219/255, 212/255))  # light lavender

# Set RGB background color for the axes (plot area)
ax[0].set_facecolor((214/255, 219/255, 212/255))  # light yellowish
ax[1].set_facecolor((214/255, 219/255, 212/255))  # light yellowish
fig.show()
# Out:
# /var/folders/nv/fbl0kxf95nj0krqsjrxv76z80000gn/T/ipykernel_54168/1724611513.py:31: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
